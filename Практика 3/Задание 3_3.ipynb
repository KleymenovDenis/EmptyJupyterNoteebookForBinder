# %%
name = list(["Д","е","н","и","с"])
sort_name = name.copy()
sort_name.sort()
union_list = name[3:] + sort_name
print(name, sort_name, union_list, sep='\n')
# Out:
# ['Д', 'е', 'н', 'и', 'с']
# ['Д', 'е', 'и', 'н', 'с']
# ['и', 'с', 'Д', 'е', 'и', 'н', 'с']
